# %%
a = "Hello World"
print(a.upper())
# Out:
# HELLO WORLD

# %%
b = "Hello World"
print(b.lower())
# Out:
# hello world

# %%
c = "Hello World"
c[:]
# Out:
# Hello World

# %%
fruit = "apple"
fruit[::-1]
# Out:
# 'elppa'

# %%
animal = "Lion"
animal[::2]
# Out:
# 'Lo'

# %%
#string formatting
name = "Rohit"
surname = "Sharma"
print(f"My name is {name} {surname}")
# Out:
# My name is Rohit Sharma

# %%
# concatination
print(name + surname)
# Out:
# RohitSharma

# %%
def slicer(mystring):
    if len(mystring) % 2 ==  0:
        return "even"
    else :
        return mystring[0]
